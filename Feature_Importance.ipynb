# %%
import numpy as np
import pandas as pd
# from nltk import bigrams,trigrams
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import re
from textblob import TextBlob

from collections import defaultdict
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.inspection import permutation_importance

# %%
X = pd.read_csv('featuresAll.csv')
xcolumnnames=X.columns

X = X.to_numpy()

Y = pd.read_csv('labels.csv')
print(Y.head())
y = Y['label']



from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score


sc = StandardScaler()
skf = StratifiedKFold(n_splits=5)
skf.get_n_splits(X, y)
clf =  GaussianNB()
print(X)
for train_ix, test_ix in skf.split(X, y):
  train_X, test_X = X[train_ix], X[test_ix]
  train_y, test_y = y[train_ix], y[test_ix]
  train_0, train_1 = len(train_y[train_y==0]), len(train_y[train_y==1])
  test_0, test_1 = len(test_y[test_y==0]), len(test_y[test_y==1])
 # print('>Train: 0=%d, 1=%d, Test: 0=%d, 1=%d' % (train_0, train_1, test_0, test_1))

  train_X = sc.fit_transform(train_X)
  #print(train_X)
  test_X = sc.transform(test_X)
  clf.fit(train_X, train_y)
  y_pred = clf.predict(test_X)
 # print(confusion_matrix(test_y,y_pred))
  #print(classification_report(test_y,y_pred))
  #print(accuracy_score(test_y, y_pred))
# Out:
#    label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# [[1.95833333e-01 3.95833333e-01 1.43000000e+02 ... 1.62500000e+00
#   3.00000000e+00 1.36039474e+02]
#  [2.50000000e-02 6.50000000e-01 1.63000000e+02 ... 1.00000000e+00
#   1.00000000e+00 2.00374025e+06]
#  [2.20000000e-01 3.28717949e-01 1.15000000e+02 ... 2.00000000e+00
#   2.00000000e+00 0.00000000e+00]
#  ...
#  [3.54545455e-01 5.17171717e-01 1.88000000e+02 ... 1.00000000e+00
#   1.00000000e+00 2.00374025e+06]
#  [6.16666667e-01 6.66666667e-01 1.04000000e+02 ... 1.00000000e+00
#   1.00000000e+00 0.00000000e+00]
#  [3.38398749e-01 5.94583133e-01 2.31000000e+03 ... 1.03448276e+00
#   2.00000000e+00 1.49235703e+02]]

# %%
imps = PermutationImportance(clf).fit(train_X, train_y)
eli5.show_weights(imps, feature_names =xcolumnnames.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0150
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 negReviewRatio
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0149
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 posReviewRatio
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0036
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avgNoOfReviews
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0005
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 polarity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0000
#
#                     &plusmn; 0.0000
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 clusterid
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 stdrating
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.75%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0001
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 meanRating
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0004
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 subjectivity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0005
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 numberOfReviews
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 98.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0008
#
#                     &plusmn; 0.0002
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 varOfSimilarity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 96.99%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0030
#
#                     &plusmn; 0.0003
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 meanSimilarity
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 91.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0129
#
#                     &plusmn; 0.0005
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 maxNoOfReviews
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 90.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0147
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 wordCount
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 90.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0147
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 avgNoOfWords
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 85.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0283
#
#                     &plusmn; 0.0004
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 totalReviews
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 80.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0447
#
#                     &plusmn; 0.0009
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 dateVariance
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0449
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 isSingleton
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>
